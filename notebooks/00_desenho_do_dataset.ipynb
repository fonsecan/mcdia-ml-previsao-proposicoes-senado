# %% [markdown]
# # 00 — Desenho do conjunto supervisionado`n`nEsta PoC prevê contagens agregadas mensais de proposições. Não usa dados pessoais nem tenta prever decisões legislativas.

# %% [markdown]
# ## Decisões a confirmar`n`n1. Recorte histórico: iniciar com cinco anos e ampliar após validar cobertura.`n2. Unidade: mês × tipo documental × tema computacional.`n3. Alvo: quantidade no mês seguinte.`n4. Avaliação: corte temporal, nunca embaralhamento aleatório.

# %% [markdown]
# ### Descrição da próxima célula de código
#
# Esta célula registra a etapa planejada de consulta e extração do histórico de processos no Senado, indicando os campos mínimos que deverão ser coletados.

# %%
# Próxima célula: consultar e extrair o histórico de processos com data de apresentação.`n# Campos mínimos: identificacao, tipo documental, data de apresentação, ementa e indexação.

# %% [markdown]
# ## Baselines obrigatórios`n`n- último valor do mesmo grupo;`n- valor do mesmo mês no ano anterior;`n- média móvel. `n`nUm modelo só avança se superar esses baselines em período futuro.
