# %% [markdown]
# # 00 — Desenho do conjunto supervisionado
#
# Esta PoC prevê contagens agregadas mensais de proposições. Não usa dados pessoais nem tenta prever decisões legislativas.

# %% [markdown]
# ## Decisões a confirmar
#
# 1. Recorte histórico: iniciar com cinco anos e ampliar após validar cobertura.
# 2. Unidade: mês × tipo documental × tema computacional.
# 3. Alvo: quantidade no mês seguinte.
# 4. Avaliação: corte temporal, nunca embaralhamento aleatório.

# %% [markdown]
# Registra a etapa planejada de consulta e extração do histórico de processos no Senado, indicando os campos mínimos que deverão ser coletados.

# %%
# Próxima célula: consultar e extrair o histórico de processos com data de apresentação.
# Campos mínimos: identificacao, tipo documental, data de apresentação, ementa e indexação.

# %% [markdown]
# ## Baselines obrigatórios
#
# - último valor do mesmo grupo;
# - valor do mesmo mês no ano anterior;
# - média móvel.
#
# Um modelo só avança se superar esses baselines em período futuro.
